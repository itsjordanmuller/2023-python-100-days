# %% [markdown]
# # Shopping Trends Data Analysis

# %% [markdown]
# ![Shopping Trends Cover Image](dataset-cover.png)

# %% [markdown]
# [Customer Shopping Trends Dataset - iamsouravbanerjee on www.kaggle.com - Dataset Link](https://www.kaggle.com/datasets/iamsouravbanerjee/customer-shopping-trends-dataset/data?select=shopping_trends.csv)
#
# https://www.kaggle.com/datasets/iamsouravbanerjee/customer-shopping-trends-dataset/data?select=shopping_trends.csv

# %% [markdown]
# ## Setup

# %% [markdown]
# > Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# > Load the dataset

# %%
file_path = "shopping_trends.csv"
trends_data = pd.read_csv(file_path)

# %% [markdown]
# > First 5 Rows (Head)

# %%
trends_data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
# 3         PayPal   Next Day Air              Yes             Yes
# 4           Cash  Free Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly
# 2                  23              Credit Card                 Weekly
# 3                  49                   PayPal                 Weekly
# 4                  31                   PayPal               Annually

# %% [markdown]
# > Last 5 Rows (Tail)

# %%
trends_data.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                  No         PayPal    Store Pickup
# 3897            2.9                  No    Credit Card        Standard
# 3898            3.8                  No         PayPal         Express
# 3899            3.1                  No  Bank Transfer    Store Pickup
#
#      Discount Applied Promo Code Used  Previous Purchases  \
# 3895               No              No                  32
# 3896               No              No                  41
# 3897               No              No                  24
# 3898               No              No                  24
# 3899               No              No                  33
#
#      Preferred Payment Method Frequency of Purchases
# 3895                    Venmo                 Weekly
# 3896            Bank Transfer              Bi-Weekly
# 3897                    Venmo              Quarterly
# 3898                    Venmo                 Weekly
# 3899                    Venmo              Quarterly

# %% [markdown]
# > Sample 10 Rows

# %%
trends_data.sample(10)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 1980         1981   51    Male        Sandals     Footwear
# 1876         1877   54    Male          Skirt     Clothing
# 1786         1787   45    Male         Jacket    Outerwear
# 2128         2129   62    Male           Coat    Outerwear
# 3267         3268   37  Female         Hoodie     Clothing
# 2221         2222   25    Male         Shorts     Clothing
# 3241         3242   50  Female        Handbag  Accessories
# 864           865   51    Male          Jeans     Clothing
# 2622         2623   63    Male       Backpack  Accessories
# 766           767   57    Male         Gloves  Accessories
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 1980                     94           Iowa    M     Green  Winter
# 1876                     36       Illinois    M      Gray    Fall
# 1786                     34       Maryland    M     Brown  Spring
# 2128                     47     New Mexico    L      Cyan    Fall
# 3267                     45          Idaho    L      Pink  Winter
# 2221                     88         Kansas   XL     White    Fall
# 3241                     58    Connecticut    M  Lavender  Summer
# 864                      59       Kentucky    S  Charcoal  Winter
# 2622                     75  New Hampshire    M    Yellow  Spring
# 766                      48         Nevada    M      Cyan  Winter
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 1980            4.4                  No          Venmo    Store Pickup
# 1876            2.6                  No    Credit Card        Standard
# 1786            4.6                  No     Debit Card  2-Day Shipping
# 2128            2.7                  No         PayPal  2-Day Shipping
# 3267            3.0                  No     Debit Card    Store Pickup
# 2221            3.0                  No     Debit Card   Free Shipping
# 3241            4.4                  No    Credit Card    Store Pickup
# 864             3.9                 Yes         PayPal    Next Day Air
# 2622            4.9                  No          Venmo  2-Day Shipping
# 766             3.6                 Yes         PayPal    Next Day Air
#
#      Discount Applied Promo Code Used  Previous Purchases  \
# 1980               No              No                  25
# 1876               No              No                  20
# 1786               No              No                  22
# 2128               No              No                  21
# 3267               No              No                  42
# 2221               No              No                  34
# 3241               No              No                  30
# 864               Yes             Yes                   5
# 2622               No              No                  15
# 766               Yes             Yes                  13
#
#      Preferred Payment Method Frequency of Purchases
# 1980                   PayPal            Fortnightly
# 1876                    Venmo              Quarterly
# 1786                    Venmo                Monthly
# 2128                   PayPal                 Weekly
# 3267              Credit Card              Quarterly
# 2221              Credit Card               Annually
# 3241                   PayPal              Quarterly
# 864                    PayPal               Annually
# 2622              Credit Card               Annually
# 766                    PayPal                Monthly

# %% [markdown]
# > Data Types & Missing Values

# %%
trends_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
#  13  Shipping Type             3900 non-null   object
#  14  Discount Applied          3900 non-null   object
#  15  Promo Code Used           3900 non-null   object
#  16  Previous Purchases        3900 non-null   int64
#  17  Preferred Payment Method  3900 non-null   object
#  18  Frequency of Purchases    3900 non-null   object
# dtypes: float64(1), int64(4), object(14)
# memory usage: 579.0+ KB

# %% [markdown]
# > Statistics Summary

# %%
trends_data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# > Unique Values

# %%
trends_data.nunique()
# Out:
# Customer ID                 3900
# Age                           53
# Gender                         2
# Item Purchased                25
# Category                       4
# Purchase Amount (USD)         81
# Location                      50
# Size                           4
# Color                         25
# Season                         4
# Review Rating                 26
# Subscription Status            2
# Payment Method                 6
# Shipping Type                  6
# Discount Applied               2
# Promo Code Used                2
# Previous Purchases            50
# Preferred Payment Method       6
# Frequency of Purchases         7
# dtype: int64

# %% [markdown]
# > Value Counts of Ages

# %%
trends_data["Age"].value_counts()
# Out:
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 50    83
# 54    83
# 27    83
# 62    83
# 32    82
# 19    81
# 58    81
# 42    80
# 43    79
# 28    79
# 31    79
# 37    77
# 46    76
# 29    76
# 68    75
# 59    75
# 63    75
# 56    74
# 36    74
# 55    73
# 52    73
# 64    73
# 35    72
# 51    72
# 65    72
# 40    72
# 45    72
# 47    71
# 66    71
# 30    71
# 23    71
# 38    70
# 53    70
# 18    69
# 21    69
# 26    69
# 34    68
# 48    68
# 24    68
# 39    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %% [markdown]
# > Value Counts of Genders

# %%
trends_data["Gender"].value_counts()
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %% [markdown]
# > Value Counts of Colors

# %%
trends_data["Color"].value_counts()
# Out:
# Color
# Olive        177
# Yellow       174
# Silver       173
# Teal         172
# Green        169
# Black        167
# Cyan         166
# Violet       166
# Gray         159
# Maroon       158
# Orange       154
# Charcoal     153
# Pink         153
# Magenta      152
# Blue         152
# Purple       151
# Peach        149
# Red          148
# Beige        147
# Indigo       147
# Lavender     147
# Turquoise    145
# White        142
# Brown        141
# Gold         138
# Name: count, dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Age Distribution

# %% [markdown]
# #### 53 Bins

# %%
sns.histplot(data=trends_data, x="Age", bins=53, kde=True)
plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### 25 Bins

# %%
sns.histplot(data=trends_data, x="Age", bins=25, kde=True)
plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Gender Distribution

# %%
gender_counts = trends_data["Gender"].value_counts()

colors = {"Male": "#5352ed", "Female": "#ff4757"}

plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct="%1.1f%%",
    colors=[colors[gender] for gender in gender_counts.index],
)
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# ### Age Distribution of Customers by Gender

# %%
colors = {"Male": "#5352ed", "Female": "#ff4757"}

sns.histplot(
    data=trends_data,
    x="Age",
    bins=53,
    kde=True,
    hue="Gender",
    palette=colors,
    multiple="dodge",
)
plt.title("Age Distribution of Customers by Gender")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Purchase Amount Distribution by Gender

# %%
colors = {"Male": "#5352ed", "Female": "#ff4757"}

sns.boxplot(data=trends_data, hue="Gender", x="Gender", y="Purchase Amount (USD)", palette=colors, legend=False)
plt.title("Purchase Amount Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Purchase Amount (USD)")
plt.show()

# %% [markdown]
# ### Color Preferences

# %%
top_10_colors = trends_data["Color"].value_counts().head(10).index

filtered_data = trends_data[trends_data["Color"].isin(top_10_colors)]

palette = sns.color_palette()

sns.countplot(
    data=filtered_data,
    y="Color",
    order=filtered_data["Color"].value_counts().index,
    palette=palette,
)

plt.title("Top 10 Color Preferences")
plt.xlabel("Count")
plt.ylabel("Color")

plt.show()
# Out:
# /tmp/ipykernel_17286/351918416.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# ### Category Wise Sales

# %%
palette = sns.color_palette()

sns.countplot(
    data=trends_data,
    y="Category",
    order=trends_data["Category"].value_counts().index,
    palette=palette,
)

plt.title("Category Wise Sales")
plt.xlabel("Count")
plt.ylabel("Category")

plt.show()
# Out:
# /tmp/ipykernel_17286/1795944322.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# /tmp/ipykernel_17286/1795944322.py:3: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.countplot(

# %% [markdown]
# ### Review Rating Distribution

# %%
sns.histplot(data=trends_data, x="Review Rating", bins=5, kde=True)
plt.title("Review Rating Distribution")
plt.xlabel("Review Rating")
plt.ylabel("Count")
plt.show()

# %%
colors = {"Male": "#5352ed", "Female": "#ff4757"}

sns.histplot(data=trends_data, x="Review Rating", bins=5, kde=True, hue="Gender", palette=colors, multiple="dodge",)

# Setting the title and labels
plt.title("Review Rating Distribution by Gender")
plt.xlabel("Review Rating")
plt.ylabel("Count")

# Display the plot
plt.show()

# %% [markdown]
# ### Seasonal Purchase Trends

# %%
sns.countplot(data=trends_data, x="Season")
plt.title("Seasonal Purchase Trends")
plt.xlabel("Season")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### Seasonal Purchase Trends by Gender

# %%
colors = {"Male": "#5352ed", "Female": "#ff4757"}

sns.countplot(data=trends_data, x="Season", hue="Gender", palette=colors)

plt.title("Seasonal Purchase Trends by Gender")
plt.xlabel("Season")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ### Payment Method Popularity

# %%
colors = {
    "Credit Card": "#e056fd",
    "Cash": "#2ed573",
    "Venmo": "#1e90ff",
    "PayPal": "#3742fa",
    "Bank Transfer": "#ff7f50",
    "Debit Card": "#eb4d4b",
}

sns.countplot(
    data=trends_data,
    y="Payment Method",
    order=trends_data["Payment Method"].value_counts().index,
    palette=[
        colors[method] for method in male_data["Payment Method"].value_counts().index
    ],
    hue="Payment Method",
    legend=False,
)
plt.title("Payment Method Popularity")
plt.xlabel("Count")
plt.ylabel("Payment Method")
plt.show()

# %% [markdown]
# #### Payment Method Popularity by Gender

# %%
colors = {
    "Credit Card": "#e056fd",
    "Cash": "#2ed573",
    "Venmo": "#1e90ff",
    "PayPal": "#3742fa",
    "Bank Transfer": "#ff7f50",
    "Debit Card": "#eb4d4b",
}

fig, axes = plt.subplots(1, 2, figsize=(14, 7))

male_data = trends_data[trends_data["Gender"] == "Male"]
sns.countplot(
    data=male_data,
    y="Payment Method",
    order=male_data["Payment Method"].value_counts().index,
    palette=[
        colors[method] for method in male_data["Payment Method"].value_counts().index
    ],
    ax=axes[0],
)
axes[0].set_title("Payment Method Popularity (Male)")
axes[0].set_xlabel("Count")
axes[0].set_ylabel("Payment Method")

female_data = trends_data[trends_data["Gender"] == "Female"]
sns.countplot(
    data=female_data,
    y="Payment Method",
    order=female_data["Payment Method"].value_counts().index,
    palette=[
        colors[method] for method in female_data["Payment Method"].value_counts().index
    ],
    ax=axes[1],
)
axes[1].set_title("Payment Method Popularity (Female)")
axes[1].set_xlabel("Count")
axes[1].set_ylabel("Payment Method")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_17286/1853970414.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# /tmp/ipykernel_17286/1853970414.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# #### Payment Method Popularity by Age

# %%
sns.catplot(x="Age", y="Payment Method", kind="box", data=trends_data, aspect=2)
plt.title("Payment Method Popularity by Age")
plt.xlabel("Age")
plt.ylabel("Payment Method")
plt.xticks(rotation=90)
plt.show()
